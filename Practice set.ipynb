# %% [markdown]
# # Practice writting python code

# %%
# Convert Celsius to Fahrenheit.
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9 / 5) + 32

print("Temperature in Fahrenheit =", fahrenheit)
# Out:
# Enter temperature in Celsius:  36
# Temperature in Fahrenheit = 96.8

# %%
# Calculate simple interest.
principal = float(input("Enter principal amount: "))
rate = float(input("Enter rate of interest: "))
time = float(input("Enter time (in years): "))

simple_interest = (principal * rate * time) / 100

print("Simple Interest =", simple_interest)
# Out:
# Enter principal amount:  50000
# Enter rate of interest:  10
# Enter time (in years):  5
# Simple Interest = 25000.0

# %%
# Find the average of three numbers.
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

average = (num1 + num2 + num3) / 3

print("Average =", average)
# Out:
# Enter first number:  56
# Enter second number:  85
# Enter third number:  82
# Average = 74.33333333333333

# %%
# Check the data type of user input.
user_input = input("Enter something: ")

print("Value:", user_input)
print("Data Type:", type(user_input))
# Out:
# Enter something:  "Hii"
# Value: "Hii"
# Data Type: <class 'str'>

# %%
# Convert minutes into hours and minutes.
minutes = int(input("Enter total minutes: "))

hours = minutes // 60
remaining_minutes = minutes % 60

print(hours, "hour(s) and", remaining_minutes, "minute(s)")
# Out:
# Enter total minutes:  65
# 1 hour(s) and 5 minute(s)
