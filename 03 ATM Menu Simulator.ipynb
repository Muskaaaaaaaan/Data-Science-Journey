# %% [markdown]
# ## Mini Project 2

# %% [markdown]
# #### ATM Menu Simulator
#
# Features:
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Requirements:
#
# Start with an initial balance.
#
# Keep showing the menu until the user chooses Exit.
#
# Validate withdrawals (don't allow overdrafts).
#
# Display the updated balance after transactions.
#
# Concepts used:while, if-elif-else, Variables, Input, break

# %%
balance = 5000
while True:
    print("\n===== ATM MENU =====")
    print("1. Check Balance")
    print("2. Deposit Money")
    print("3. Withdraw Money")
    print("4. Exit")
    choice = int(input("Enter your choice: "))
    if choice == 1:
        print("Your Balance is Rs.", balance)
    elif choice == 2:
        amount = int(input("Enter amount to deposit: "))
        balance = balance + amount
        print("Money Deposited Successfully.")
        print("Updated Balance = Rs.", balance)
    elif choice == 3:
        amount = int(input("Enter amount to withdraw: "))
        if amount <= balance:
            balance = balance - amount
            print("Please collect your cash.")
            print("Updated Balance = Rs.", balance)
        else:
            print("Insufficient Balance.")
    elif choice == 4:
        print("Thank you for using our ATM.")
        break
    else:
        print("Invalid Choice. Please try again.")
# Out:
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice:  1
# Your Balance is Rs. 5000
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice:  2
# Enter amount to deposit:  2000
# Money Deposited Successfully.
# Updated Balance = Rs. 7000
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice:  3
# Enter amount to withdraw:  3000
# Please collect your cash.
# Updated Balance = Rs. 4000
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice:  3
# Enter amount to withdraw:  5000
# Insufficient Balance.
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter your choice:  2
# Enter amount to deposit:  500
# Money Deposited Successfully.
# Updated Balance = Rs. 4500
#
# ===== ATM MENU =====
# 1. Check Balance
# ...
